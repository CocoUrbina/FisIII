# %% [markdown]
# # Andrés

# %% [markdown]
# $L_{eq}=L_2 + L_3 + 2\sigma M_{23}$
#
# $\displaystyle L_{eq}= \frac{L_1 L_4 -M_{14}^2}{L_1 + L_4 -\sigma_{14} M_{14}}$
#
# ---
# $V = \frac{q}{C}$
#
# $\displaystyle U_C= \frac{1}{2} CV^2$
#
# $q_C = q_m e^{-Rt/2L} \cos (\omega t + \phi)$
#
# $i = \frac{dq}{dt} $
#
# ---
#
# $V = IR$
#
# $\bar{X}_L = jX_L = j\omega L$
#
# $\bar{X}_C = -jX_C = -j / \omega C$
#
# ---
# $\mathcal{E} = I_C X_C$
#
# $\mathcal{E} = IZ$
#
# ---
#
# $\displaystyle \int \vec{S} \cdot d\vec{A} = \frac{\partial U}{\partial t}$
#
# $\displaystyle U = \frac{1}{2} \epsilon_0 E^2 V$
#
# $\displaystyle \vec{B} \cdot d\vec{s} = \mu_0 I - \epsilon_0 \mu_0 \frac{\partial \Phi_E}{\partial t}$

# %% [markdown]
# # Tarea

# %% [markdown]
# $U_T = U_L + U_C$
#
# $\displaystyle U_L = \frac{1}{2} LI^2$
#
# $\displaystyle U_C = \frac{1}{2}CV^2 = \frac{1}{2} \frac{q^2}{C}$
#
# $\displaystyle \frac{dU}{dt} = -RI^2$
#
# $I = qt$ $I = \frac{dq}{dt}$ ??
#
# $q = A_1 \exp(s_1t) + A_2 \exp(s_2t)$
#
# $q = \exp(-Rt/2L) (q_m + At)$
#
# $q = \exp(-Rt/2L) \cos(w^\prime t + \phi)$
#
# ---
# $U$
#
# ---
#
# $\displaystyle Z = \frac{V}{I}$
#
# ---
#
# $F = F_m \cos(\omega^{\prime \prime} t)$
#
# $I = I_m \sin(\omega^{\prime \prime} t - \phi)$
#
# $P_F = F_mi_m \sin(\omega t) \sin(\omega t - \phi)$
#
# $P_F^m = \frac{1}{2}F_mi_m \cos( \phi) = F_{rsm}i_{rsm} \cos(\phi)$

# %% [markdown]
# # EM

# %% [markdown]
# $\displaystyle \oint \vec{E}\cdot d\vec{A} = q/\epsilon_0$
#
# $\displaystyle \oint \vec{B}\cdot d\vec{A} = 0$
#
# $\displaystyle \oint \vec{E}\cdot d\vec{s} = -d \Phi_B / dt$
#
# $\displaystyle \oint \vec{B}\cdot d\vec{s} = \mu_0i +\mu_0 \epsilon_0 d \Phi_E / dt$
#
# $\displaystyle i_D = \epsilon_0 d \Phi_E / dt $
#
# $E(y,t) = E_m \sin(ky - wt)$
#
# $B(y,t) = B_m \cos(ky - wt)$
#
# $\displaystyle \frac{\partial E}{\partial y} = - \frac{\partial B}{\partial t}$
#
# $E_m = cB_m$
#
# $\displaystyle -\frac{\partial B}{\partial y} = \mu_0 \epsilon_0 \frac{\partial E}{\partial t}$
#
# $\displaystyle c = \frac{1}{\sqrt{\mu_0 \epsilon_0}}$
#
# $U_E = \frac{1}{2} \epsilon_0 E^2$
#
# $U_B = \frac{1}{2 \mu_0}  B^2$
#
# ---
#
# $\lambda f = c$
#
# $I=\displaystyle \left \langle \vec{S} \right \rangle = \frac{1}{\mu_0 c} E_m^2$
#
# $\displaystyle \left \langle P \right \rangle = \frac{I_m V_m}{2} \cos(\phi)$
#
# $V = IZ$
#
# $\displaystyle P_R = \frac{V^2}{R} $
#
# $w_0 = \frac{1}{\sqrt(LC)}$
#
#
# $ \Delta q = i \Delta t $
#
# $E = \frac{\sigma}{\epsilon_0}$
#
# $V = Ed$
#
# $J_d = \epsilon_0 dE/dt$
#
# $i_d = J_d A$
#
# $i_d = i_c$
